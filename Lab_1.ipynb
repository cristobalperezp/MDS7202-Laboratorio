# %% [markdown]
# <a href="https://colab.research.google.com/github/cristobalperezp/MDS7202-Laboratorio/blob/main/Lab_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1><center>Laboratorio 1: Git 👾</center></h1>
#
# <center><strong>MDS7202: Laboratorio de Programación Científica para Ciencia de Datos - Otoño 2023</strong></center>

# %% [markdown]
# ### Cuerpo Docente:
#
# - Profesores: Pablo Badilla, Ignacio Meza D.
# - Auxiliar: Sebastián Tinoco
# - Ayudante: Diego Cortez

# %% [markdown]
# ### Equipo: SUPER IMPORTANTE - notebooks sin nombre no serán revisados
#
# - Nombre de alumno 1: Cristóbal Pérez P.
# - Nombre de alumno 2: Patricio Pérez.

# %% [markdown]
# ### **Link de repositorio de GitHub:** `https://github.com/cristobalperezp/MDS7202-Laboratorio`

# %% [markdown]
# ## Reglas:
#
# - Fecha de entrega: 6 días desde la publicación, 3 días de atraso con 1 punto de descuento c/u. Pueden utilizar días bonus sin descuento.
# - **Grupos de 2 personas**.
# - **Ausentes** deberán realizar la actividad solos.
# - Cualquier duda fuera del horario de clases al foro. Mensajes al equipo docente serán respondidos por este medio.
# - <u>Prohibidas las copias</u>. Cualquier intento de copia será debidamente penalizado con el reglamento de la escuela.
# - Pueden usar cualquer material del curso que estimen conveniente.
# - Asistencia obligatoria a instrucciones del lab (viernes 16.15). Luego, pueden quedarse trabajando en las salas o irse.

# %% [markdown]
# ## Objetivos del lab:
#
#
# - Conocer los elementos básicos que conformar `Git`
# - Clonar repositorios
# - Identificar ramas de un repositorio
# - Reconocer y solucionar problemas entre ramas
# - Subir cambios a un repositorio

# %% [markdown]
# ## Parte 1: Conocimiento Teórico (2 pts)

# %% [markdown]
# Responda las siguientes preguntas (0.2 pts c/u):
#
# 1. ¿Qué es `Git` y cómo se relaciona con el control de versiones?
#
#
# 2. Nombre y explique 3 diferencias entre `Git` y `Github`.
#
#
# 3. ¿Qué es un `hash` y cómo se representa en un `commit`? De un ejemplo.
#
#
# 4. ¿Que elementos componen a la estructura de datos de `Git`?
#
#
# 5. ¿Que comandos de `Git` sirven para crear un repositorio y hacer seguimiento a cambios en los archivos?

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
#
#
# **P1 R:**
#
# Es un sistema de control de versiones de código abierto. Un repositorio es un conjunto de carpetas y archivos en el que se almacena el código de un proyecto más el historial de cambios de cada archivo, Git administra los registros a través de archivos en una carpeta oculta llamada .git.
#
# **P2 R:**
#
# *   Git es un sistema de control de versiones distribuido, en cambio Github es un servicio de alojamiento basado en web.
# *   Es una herramienta de líneas de comando, Github entrega una interfaz gráfica.
# *   Git crea un repositorio local para trackear los cambios locales, y Github es un espacio para subir una copia de los repositorios de Git.
#
# **P3 R:**
#
# Los hash son identificadores de 40 caracteres, que permiten referenciar a un elemento de interés, cada elemento posee un hash único.
#
# Un commit tiene una estructura que consta de 3 elementos: autor, momento de realización de la modificación y el hash identificador del cambio.
#
# Ejemplo obtenido de la clase:
# ![image.png](data:image/png;base64,...)
#
# **P4 R:**
#
# Para la estructura de datos de Git se pueden nombrar los siguientes elementos:
#
# *  Commits: snapshots/capturas que se guardan en el historial que registran y consolidan los  cambios.
# *  Blob: unidad básica de almacenamiento, todo el contenido de un archivo se guarda en blobs, cuando un archivo es modificado, un nuevo blob
# almacenará el archivo completo con todos los nuevos
# cambios.
# *  Carpetas o Directorios: todos los archivos se almacenan en un directorio o carpeta, las carpetas pueden contener más directorios.
# *  Árbol: representa directorios para blobs y más árboles, siempre hay un árbol en la raíz, apuntando al árbol que contiene cosas.
# *  Hash: son identificadores de 40 caracteres, que permiten referenciar a un elemento de interés, cada elemento posee un hash único.
#
# **P5 R:**
#
# Para crear un repositorio desde cero se usa:
#
# <code>>> git init nombre-del-repo</code>
#
# Reemplazando "nombre-del-repo" por el nombre que queremos darle al repositorio.
#
# Para hacer seguimiento a cambios en los archivos podemos utilizar:
#
# <code>>> git log</code>
#
# Con este podemos observar el registro de cambios.

# %% [markdown]
# Responda si las siguientes afirmaciones son Verdaderas (V) o Falsas (F). Justifique en **cualquiera** de los casos (0.2 pts c/u):
#
#
# 6. `Git` siempre resuelve automáticamente los problemas de lineas al hacer merge entre diferentes ramas.
# 7. Ejecutar `git pull` sobre un repositorio es equivalente a ejecutar `git clone`.
# 8. Cada miembro del equipo trabaja en la misma copia del código fuente usando `Git`.
# 9. En `Git` es posible deshacer cambios y volver a versiones anteriores del código.
# 10. El comando `git commit` se utiliza para enviar cambios al repositorio remoto.

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>

# %% [markdown]
# ## Parte 2: Creando una presentación personal (2 pts)

# %% [markdown]
# Para empezar a "*soltar las manos*" con `Git`, se les encomienda crear un repositorio con una presentación personal. El repositorio debe contener un breve resumen de quienes son ustedes, sus gustos, experiencias, y cualquier otro detalle interesante que ustedes consideren relevante.
#
# Para realizar esto, deben seguir los siguientes pasos:
#
# 1. Contar con una cuenta de github (1 por persona)
# 2. Crear un repositorio con su nombre de usuario
# 3. Crear y modificar un archivo `readme.md` con la información que ustedes deseen compartir.
#
# A modo de ejemplo, pueden guiarse por esta *suculenta* [presentación](https://github.com/pbadillatorrealba/pbadillatorrealba).
#
# *Hint: Una buena opción es usar templates de presentación personal que encuentren en Google, como los que ofrece este [sitio](https://durgeshsamariya.github.io/awesome-github-profile-readme-templates/#/)*.
#
# **Entregable:**
#
# Enlace al repositorio con la presentación personal.
#
# IMPORTANTE: DEBEN ADJUNTAR UN ENLACE POR PERSONA

# %% [markdown]
# <code>Link Presentacion 1:</code>
#
# <code>Link Presentacion 2: https://github.com/cristobalperezp/cristobal_perez_p/blob/main/README.md</code>

# %% [markdown]
# ## Parte 3: Trabajando sobre un repositorio externo (2 pts)

# %% [markdown]
# Tras muchos dolores de cabeza, un grupo de entusiastas académicos decidieron aprender sobre `Git` y así trabajar colaborativamente de forma más ordenada y eficiente. Después de una infinidad de intentos y aprender de sus errores "*a la mala*", los académicos lograron levantar un [repositorio](https://github.com/MDS7202/lab1) en `Github`. Usando el repositorio de los académicos, responda las siguientes preguntas (incluya también los comandos en `Git` ocupados):

# %% [markdown]
# 1. Clone el repositorio a su ambiente local. (0.25 pts)

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
#
# Con la siguiente línea de comando podemos copiar el repositorio en el ambiente local:
#
# <code>% git clone https://github.com/MDS7202/lab1.git</code>
#
# ![image.png](data:image/png;base64,...)
#
# En este caso ha sido clonado en la carpeta lab1 del escritorio.

# %% [markdown]
# 2. Inspeccione brevemente el repositorio: ¿Cual es el objetivo del proyecto? Explique brevemente la estructura del proyecto, asi como también de cada componente que lo conforma. (0.25 pts)

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
#
# El proyecto consta de emular el sonido de los animales, lo cuál se encuentra en el archivo readme.md del repositorio.
#
# La estructura del repositorio consta de 3 archivos, el readme antes mencionado, y dos archivos con extención .py: main y animales, esto lo podemos ver con la siguiente linea de comandp:
#
# <code>% git ls-tree --name-only HEAD</code>
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 3. Identifique los últimos cambios al repositorio, reconociendo las principales ramas de trabajo. ¿Son informativos los `commit` realizados? (0.25 pts)
# *Hint: Se recomienda usar los argumentos `all`, `graph` y `decorate`*

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
#
# Con el siguiente comando podemos tener el historial de confirmaciones y las ramas del repositorio con una representación gráfica de la estructura de ramas, con los nombres de las ramas y las etiquetas que apuntan a cada confirmación.
#
# <code>% git log --all --graph --decorate </code>
#
# ![image.png](data:image/png;base64,...)
#
# Así las principales ramas son: main, new_features y fix-ifs.
#
# Los commit ingresados no son del todo informativos, sobretodo los que tienen como comentarios "fix ifs" y "se agrega función", el primero no informa de lo realizado y el segundo no da detalle de qué funciones se agregaron ni su fuincionalidad específica.

# %% [markdown]
# 4. Uno de los académicos se da cuenta que la rama principal de trabajo no se ejecuta correctamente para todos los argumentos. Señale el error en el código e identifique a la persona que lo cometió usando `git blame` (0.25 pts)
#
# *Hint: Le puede ser útil esta [documentación](https://www.atlassian.com/es/git/tutorials/inspecting-a-repository/git-blame).*

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
#
# Encontramos el error en el archivo animales.py después de ejecutar el archivo main con perro, gato y otros animales, se da el siguiente mensaje al probar con perro y gato:
# ![image.png](data:image/png;base64,...)
#
# Cuando si se reconoce el animal, con el comando:
#
# <code>% git blame animales.py</code>
#
# Vemos que en la 9 y 11 se utilizó if cuando debieron ser utilizados elif para que el programa se ejecute correctamente, error que fue cometido por mezosky el 23-03-2023:
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 5. Busque los siguientes `commit`:
#
# - `c8b1a62d7299552b0654f930d695b33109214111`
# - `362fe21ee44f53ee944cee4ba484600308f83d78`
# - `25543a3baf77292baf849726784ca005473acab1`
#
# ¿Qué diferencias existen entre cada uno? (0.25 pts)

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
#
# Al buscar los 3 commit con <code>%git log --oneline</code> entrega la siguiente información:
#
#
# Para encontrar las diferencias entre estos commit, utilizamos <code>% git diff </code> para los dos primeros commit tenemos cambios en animales.py y main.py, dónde se crea ell archivo animales con el error antes visto, y el main con todo este código de animales.py, que se elimina, que se elimina y pasa a ser importado.
#
# ![image.png](data:image/png;base64,...)
#
# Entre los dos últimos se corrige el error con los ifs en animales.py y en main se borra y agrega la última línea de código.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 6. Realice una `merge` de la rama `fix-ifs` con la rama `main` y describa lo que ocurre. ¿Qué parte del código podría estar ocasionando esto? (0.25 pts)

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
#
# Al hacer <code>% git merge fix-ifs</code>, arroja el siguiente mensaje en el merge:
#
# ![image.png](data:image/png;base64,...)
#
# Lo que nos indica que el conflicto se encuentra en el archivo main.py, con <code>% vim main.py</code>ingresamos al archivo y vemos que lo que genera conflicto es la parte en que se define la función animalitos vs el uso del import de esta función desde el archivo animales.py para no volver a definirlo dentro del main.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 7. Cree una rama nueva y proponga una solución al problema anterior, adjuntando el código corregido y señalando las líneas modificadas. (0.5 pts)

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
#
# Se crea la nueva rama reparo-ifs estando en main:
#
# <code>% git chekout -b reparo-ifs</code>
#
# Se modifica el archivo main.py para dejar sólo la importación y no la función para corregir el conflicto.
#
# ![image.png](data:image/png;base64,...)
#
# Se realiza git add y commit:
#
# <code>% git add .</code>
#
# <code>% git commit -m "reparo de conflicto en archivo main.py dejando solo el import"</code>
#
# Finalmente se hace merge.
#
# <code>% git merge origin/fix-ifs</code>
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Fin

# %% [markdown]
# Eso ha sido todo por ahora!! Esperamos que este laboratorio les haya gustado y servido para trabajar con `Git`. Recuerden los dias de plazo que tienen disponibles y que ante cualquier duda no duden en contactar al equipo docente.
#
# Nos vemos!!
#
# <img src=https://media.tenor.com/OYLdav9k9LkAAAAd/kitty-cat.gif height=300>
